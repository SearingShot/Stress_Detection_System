# %% [markdown]
# - Here We Are Trying to build a Model For Stress Detection Using Facial Emotions, Which Will Firstly Detect Facial Emotions , Based On which It will Tell us whether the person is Stressed Or Not.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy'] )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "train1", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 375 images belonging to 7 classes.
# {'Angry': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "train1", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 375 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch=10, 
                           epochs=30, 
                           validation_data=val_data, 
                           validation_steps=8, 
                           callbacks=[es, mc])
# Out:
# C:\Users\Ritika\AppData\Local\Temp\ipykernel_19676\70827438.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 8.9031 - accuracy: 0.2186
# Epoch 1: val_accuracy improved from -inf to 0.54688, saving model to best_model.h5
# 10/10 [==============================] - 78s 5s/step - loss: 8.9031 - accuracy: 0.2186 - val_loss: 3.1576 - val_accuracy: 0.5469
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 3.3764 - accuracy: 0.5756
# Epoch 2: val_accuracy improved from 0.54688 to 0.69531, saving model to best_model.h5
# 10/10 [==============================] - 21s 2s/step - loss: 3.3764 - accuracy: 0.5756 - val_loss: 1.7606 - val_accuracy: 0.6953
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 1.5713 - accuracy: 0.7460
# Epoch 3: val_accuracy improved from 0.69531 to 0.78516, saving model to best_model.h5
# 10/10 [==============================] - 23s 2s/step - loss: 1.5713 - accuracy: 0.7460 - val_loss: 1.2722 - val_accuracy: 0.7852
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 1.1141 - accuracy: 0.7878
# Epoch 4: val_accuracy improved from 0.78516 to 0.85547, saving model to best_model.h5
# 10/10 [==============================] - 15s 2s/step - loss: 1.1141 - accuracy: 0.7878 - val_loss: 0.7302 - val_accuracy: 0.8555
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6853 - accuracy: 0.8650
# Epoch 5: val_accuracy improved from 0.85547 to 0.93359, saving model to best_model.h5
# 10/10 [==============================] - 14s 1s/step - loss: 0.6853 - accuracy: 0.8650 - val_loss: 0.2729 - val_accuracy: 0.9336
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3257 - accuracy: 0.9260
# Epoch 6: val_accuracy did not improve from 0.93359
# 10/10 [==============================] - 11s 1s/step - loss: 0.3257 - accuracy: 0.9260 - val_loss: 0.2982 - val_accuracy: 0.9180
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3915 - accuracy: 0.9125
# Epoch 7: val_accuracy did not improve from 0.93359
# 10/10 [==============================] - 11s 1s/step - loss: 0.3915 - accuracy: 0.9125 - val_loss: 0.4147 - val_accuracy: 0.9180
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.9293
# Epoch 8: val_accuracy improved from 0.93359 to 0.94531, saving model to best_model.h5
# 10/10 [==============================] - 14s 1s/step - loss: 0.3536 - accuracy: 0.9293 - val_loss: 0.2964 - val_accuracy: 0.9453
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.9389
# Epoch 9: val_accuracy improved from 0.94531 to 0.97656, saving model to best_model.h5
# 10/10 [==============================] - 14s 1s/step - loss: 0.3083 - accuracy: 0.9389 - val_loss: 0.0614 - val_accuracy: 0.9766
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1451 - accuracy: 0.9614
# Epoch 10: val_accuracy improved from 0.97656 to 0.98438, saving model to best_model.h5
# 10/10 [==============================] - 15s 2s/step - loss: 0.1451 - accuracy: 0.9614 - val_loss: 0.0748 - val_accuracy: 0.9844
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.9550
# Epoch 11: val_accuracy improved from 0.98438 to 0.99219, saving model to best_model.h5
# 10/10 [==============================] - 13s 1s/step - loss: 0.1797 - accuracy: 0.9550 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9582
# Epoch 12: val_accuracy did not improve from 0.99219
# 10/10 [==============================] - 12s 1s/step - loss: 0.0932 - accuracy: 0.9582 - val_loss: 0.0838 - val_accuracy: 0.9766
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9743
# Epoch 13: val_accuracy improved from 0.99219 to 1.00000, saving model to best_model.h5
# 10/10 [==============================] - 14s 1s/step - loss: 0.0876 - accuracy: 0.9743 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9839
# Epoch 14: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0595 - accuracy: 0.9839 - val_loss: 0.0142 - val_accuracy: 0.9922
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9871
# Epoch 15: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0378 - accuracy: 0.9871 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 16/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9875
# Epoch 16: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0551 - accuracy: 0.9875 - val_loss: 0.0544 - val_accuracy: 0.9883
# Epoch 16: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "train1\Happy\check4.jpeg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
#  the image is of Happy
